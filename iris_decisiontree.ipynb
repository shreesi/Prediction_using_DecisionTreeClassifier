# %% [markdown]
# # Prediction using Decision Tree Classifier

# %% [markdown]
# # Shree Narayan Teli

# %%
# importing the necessary library

import pandas as pd 
from sklearn import tree
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading our dataset using read_csv method of pandas

iris = pd.read_csv('iris.csv')

# %%
# Here we have printed five rows using head method

iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Finding the number of rows and columns in the dataset

iris.shape
# Out:
# (150, 6)

# %%
# we have printed the datatypes and checked that is there any null values present in the dataset or not.

iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# Dropping the ID column from our dataset as it does not require

iris.drop('Id', axis=1, inplace = True)

# %%
iris.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 66             5.6           3.0            4.5           1.5  Iris-versicolor
# 105            7.6           3.0            6.6           2.1   Iris-virginica
# 69             5.6           2.5            3.9           1.1  Iris-versicolor
# 35             5.0           3.2            1.2           0.2      Iris-setosa
# 135            7.7           3.0            6.1           2.3   Iris-virginica

# %%
# Spliting dataset into input and target variables

input = iris.drop('Species', axis=1)
target = iris['Species']

# %%
dtc = tree.DecisionTreeClassifier()

# %%
# Here we have fitted our data to the Decision Tree Classifier model

dtc.fit(input, target)
# Out:
# DecisionTreeClassifier()

# %%
#Finding the score of our model

dtc.score(input, target)
# Out:
# 1.0

# %%
# Plotting the tree graph and visualizing graphically

feature = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
clas = ['Iris-setosa','Iris-versicolor','Iris-virginica']

plt.figure(figsize=(20,10))
tree.plot_tree(dtc,feature_names=feature,class_names=clas, filled=True)
# Out:
# [Text(0.5, 0.9166666666666666, 'PetalLengthCm <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = Iris-setosa'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = Iris-setosa'),
#  Text(0.5769230769230769, 0.75, 'PetalWidthCm <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = Iris-versicolor'),
#  Text(0.3076923076923077, 0.5833333333333334, 'PetalLengthCm <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]\nclass = Iris-versicolor'),
#  Text(0.15384615384615385, 0.4166666666666667, 'PetalWidthCm <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]\nclass = Iris-versicolor'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]\nclass = Iris-versicolor'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = Iris-virginica'),
# ...

# %%
# Predicting

dtc.predict([[5.1,3.5,1.4,0.2]])
# Out:
# C:\Users\shree\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-setosa'], dtype=object)

# %%
dtc.predict([[6.6,3.0,4.4,1.4]])
# Out:
# C:\Users\shree\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['Iris-versicolor'], dtype=object)
